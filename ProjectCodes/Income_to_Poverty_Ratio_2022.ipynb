# %%
import pandas as pd
import numpy as np

data = pd.read_csv("ACSDT5Y2022.C17002-Data.csv")
data.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US290019501001  Block Group 1; Census Tract 9501; Adair County...
# 2  1500000US290019501002  Block Group 2; Census Tract 9501; Adair County...
# 3  1500000US290019501003  Block Group 3; Census Tract 9501; Adair County...
# 4  1500000US290019502001  Block Group 1; Census Tract 9502; Adair County...
#
#         C17002_001E              C17002_001M                  C17002_002E  \
# 0  Estimate!!Total:  Margin of Error!!Total:  Estimate!!Total:!!Under .50
# 1              1121                      187                           86
# 2              1589                      304                          192
# 3               961                      247                           34
# 4              1029                      218                           57
#
#                           C17002_002M                   C17002_003E  \
# 0  Margin of Error!!Total:!!Under .50  Estimate!!Total:!!.50 to .99
# 1                                  57                             7
# 2                                 250                            65
# 3                                  25                            66
# 4                                  40                           182
#
#                            C17002_003M                     C17002_004E  \
# 0  Margin of Error!!Total:!!.50 to .99  Estimate!!Total:!!1.00 to 1.24
# 1                                   11                              91
# 2                                   63                              41
# 3                                   39                              10
# 4                                   97                             168
#
#                              C17002_004M                     C17002_005E  \
# 0  Margin of Error!!Total:!!1.00 to 1.24  Estimate!!Total:!!1.25 to 1.49
# 1                                    108                              52
# 2                                     38                              33
# 3                                      8                              97
# 4                                    108                              77
#
#                              C17002_005M                     C17002_006E  \
# 0  Margin of Error!!Total:!!1.25 to 1.49  Estimate!!Total:!!1.50 to 1.84
# 1                                     41                               0
# 2                                     44                              51
# 3                                     99                             196
# 4                                     75                              20
#
#                              C17002_006M                     C17002_007E  \
# 0  Margin of Error!!Total:!!1.50 to 1.84  Estimate!!Total:!!1.85 to 1.99
# 1                                     12                               4
# 2                                     46                             118
# 3                                    172                               9
# 4                                     18                              12
#
#                              C17002_007M                      C17002_008E  \
# 0  Margin of Error!!Total:!!1.85 to 1.99  Estimate!!Total:!!2.00 and over
# 1                                      6                              881
# 2                                    146                             1089
# 3                                     10                              549
# 4                                     13                              513
#
#                               C17002_008M  Unnamed: 18
# 0  Margin of Error!!Total:!!2.00 and over          NaN
# 1                                     166          NaN
# 2                                     239          NaN
# 3                                     186          NaN
# 4                                     149          NaN

# %%
data[['BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE']] = data['NAME'].str.split(';', expand=True)
data.drop(columns=['NAME'], inplace=True)
data['BLOCK_GROUP'] = data['BLOCK_GROUP'].str.strip()
data['CENSUS_TRACT'] = data['CENSUS_TRACT'].str.replace('County', '').str.strip()
data['COUNTIES'] = data['COUNTIES'].str.strip()
data['STATE'] = data['STATE'].str.strip()
data.head()
# Out:
#                   GEO_ID       C17002_001E              C17002_001M  \
# 0              Geography  Estimate!!Total:  Margin of Error!!Total:
# 1  1500000US290019501001              1121                      187
# 2  1500000US290019501002              1589                      304
# 3  1500000US290019501003               961                      247
# 4  1500000US290019502001              1029                      218
#
#                    C17002_002E                         C17002_002M  \
# 0  Estimate!!Total:!!Under .50  Margin of Error!!Total:!!Under .50
# 1                           86                                  57
# 2                          192                                 250
# 3                           34                                  25
# 4                           57                                  40
#
#                     C17002_003E                          C17002_003M  \
# 0  Estimate!!Total:!!.50 to .99  Margin of Error!!Total:!!.50 to .99
# 1                             7                                   11
# 2                            65                                   63
# 3                            66                                   39
# 4                           182                                   97
#
#                       C17002_004E                            C17002_004M  \
# 0  Estimate!!Total:!!1.00 to 1.24  Margin of Error!!Total:!!1.00 to 1.24
# 1                              91                                    108
# 2                              41                                     38
# 3                              10                                      8
# 4                             168                                    108
#
#                       C17002_005E  ...                            C17002_006M  \
# 0  Estimate!!Total:!!1.25 to 1.49  ...  Margin of Error!!Total:!!1.50 to 1.84
# 1                              52  ...                                     12
# 2                              33  ...                                     46
# 3                              97  ...                                    172
# 4                              77  ...                                     18
#
#                       C17002_007E                            C17002_007M  \
# 0  Estimate!!Total:!!1.85 to 1.99  Margin of Error!!Total:!!1.85 to 1.99
# 1                               4                                      6
# 2                             118                                    146
# 3                               9                                     10
# 4                              12                                     13
#
#                        C17002_008E                             C17002_008M  \
# 0  Estimate!!Total:!!2.00 and over  Margin of Error!!Total:!!2.00 and over
# 1                              881                                     166
# 2                             1089                                     239
# 3                              549                                     186
# 4                              513                                     149
#
#   Unnamed: 18           BLOCK_GROUP       CENSUS_TRACT      COUNTIES     STATE
# 0         NaN  Geographic Area Name               None          None      None
# 1         NaN         Block Group 1  Census Tract 9501  Adair County  Missouri
# 2         NaN         Block Group 2  Census Tract 9501  Adair County  Missouri
# 3         NaN         Block Group 3  Census Tract 9501  Adair County  Missouri
# 4         NaN         Block Group 1  Census Tract 9502  Adair County  Missouri
#
# [5 rows x 22 columns]

# %%
data = data[['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + 
            [col for col in data.columns if col not in ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT',
                                                        'COUNTIES', 'STATE']]]
data.head()
# Out:
#                   GEO_ID           BLOCK_GROUP       CENSUS_TRACT  \
# 0              Geography  Geographic Area Name               None
# 1  1500000US290019501001         Block Group 1  Census Tract 9501
# 2  1500000US290019501002         Block Group 2  Census Tract 9501
# 3  1500000US290019501003         Block Group 3  Census Tract 9501
# 4  1500000US290019502001         Block Group 1  Census Tract 9502
#
#        COUNTIES     STATE       C17002_001E              C17002_001M  \
# 0          None      None  Estimate!!Total:  Margin of Error!!Total:
# 1  Adair County  Missouri              1121                      187
# 2  Adair County  Missouri              1589                      304
# 3  Adair County  Missouri               961                      247
# 4  Adair County  Missouri              1029                      218
#
#                    C17002_002E                         C17002_002M  \
# 0  Estimate!!Total:!!Under .50  Margin of Error!!Total:!!Under .50
# 1                           86                                  57
# 2                          192                                 250
# 3                           34                                  25
# 4                           57                                  40
#
#                     C17002_003E  ...                            C17002_004M  \
# 0  Estimate!!Total:!!.50 to .99  ...  Margin of Error!!Total:!!1.00 to 1.24
# 1                             7  ...                                    108
# 2                            65  ...                                     38
# 3                            66  ...                                      8
# 4                           182  ...                                    108
#
#                       C17002_005E                            C17002_005M  \
# 0  Estimate!!Total:!!1.25 to 1.49  Margin of Error!!Total:!!1.25 to 1.49
# 1                              52                                     41
# 2                              33                                     44
# 3                              97                                     99
# 4                              77                                     75
#
#                       C17002_006E                            C17002_006M  \
# 0  Estimate!!Total:!!1.50 to 1.84  Margin of Error!!Total:!!1.50 to 1.84
# 1                               0                                     12
# 2                              51                                     46
# 3                             196                                    172
# 4                              20                                     18
#
#                       C17002_007E                            C17002_007M  \
# 0  Estimate!!Total:!!1.85 to 1.99  Margin of Error!!Total:!!1.85 to 1.99
# 1                               4                                      6
# 2                             118                                    146
# 3                               9                                     10
# 4                              12                                     13
#
#                        C17002_008E                             C17002_008M  \
# 0  Estimate!!Total:!!2.00 and over  Margin of Error!!Total:!!2.00 and over
# 1                              881                                     166
# 2                             1089                                     239
# 3                              549                                     186
# 4                              513                                     149
#
#   Unnamed: 18
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 22 columns]

# %%
new_headers = data.iloc[0, 5:].tolist()
new_headers = ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + new_headers
data.columns = new_headers
data = data.drop(index=0)
data.head()
# Out:
#                   GEO_ID    BLOCK_GROUP       CENSUS_TRACT      COUNTIES  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       STATE Estimate!!Total: Margin of Error!!Total:  \
# 1  Missouri             1121                     187
# 2  Missouri             1589                     304
# 3  Missouri              961                     247
# 4  Missouri             1029                     218
# 5  Missouri              998                     247
#
#   Estimate!!Total:!!Under .50 Margin of Error!!Total:!!Under .50  \
# 1                          86                                 57
# 2                         192                                250
# 3                          34                                 25
# 4                          57                                 40
# 5                          28                                 26
#
#   Estimate!!Total:!!.50 to .99  ... Margin of Error!!Total:!!1.00 to 1.24  \
# 1                            7  ...                                   108
# 2                           65  ...                                    38
# 3                           66  ...                                     8
# 4                          182  ...                                   108
# 5                          125  ...                                     6
#
#   Estimate!!Total:!!1.25 to 1.49 Margin of Error!!Total:!!1.25 to 1.49  \
# 1                             52                                    41
# 2                             33                                    44
# 3                             97                                    99
# 4                             77                                    75
# 5                              5                                     8
#
#   Estimate!!Total:!!1.50 to 1.84 Margin of Error!!Total:!!1.50 to 1.84  \
# 1                              0                                    12
# 2                             51                                    46
# 3                            196                                   172
# 4                             20                                    18
# 5                             38                                    32
#
#   Estimate!!Total:!!1.85 to 1.99 Margin of Error!!Total:!!1.85 to 1.99  \
# 1                              4                                     6
# 2                            118                                   146
# 3                              9                                    10
# 4                             12                                    13
# 5                             49                                    42
#
#   Estimate!!Total:!!2.00 and over Margin of Error!!Total:!!2.00 and over NaN
# 1                             881                                    166 NaN
# 2                            1089                                    239 NaN
# 3                             549                                    186 NaN
# 4                             513                                    149 NaN
# 5                             749                                    234 NaN
#
# [5 rows x 22 columns]

# %%
def clean_column_name(column_name):
    column_name = str(column_name)
    column_name = column_name.replace("!!", "_")
    column_name = column_name.replace(" ", "_")
    column_name = column_name.lower()
    column_name = ''.join(char if char.isalnum() or char == '_' else '' for char in column_name)
    return column_name

cleaned_column_names = [clean_column_name(col) for col in data.columns]
data.columns = cleaned_column_names
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total estimate_total_under_50  \
# 1  Missouri           1121                   187                      86
# 2  Missouri           1589                   304                     192
# 3  Missouri            961                   247                      34
# 4  Missouri           1029                   218                      57
# 5  Missouri            998                   247                      28
#
#   margin_of_error_total_under_50 estimate_total_50_to_99  ...  \
# 1                             57                       7  ...
# 2                            250                      65  ...
# 3                             25                      66  ...
# 4                             40                     182  ...
# 5                             26                     125  ...
#
#   margin_of_error_total_100_to_124 estimate_total_125_to_149  \
# 1                              108                        52
# 2                               38                        33
# 3                                8                        97
# 4                              108                        77
# 5                                6                         5
#
#   margin_of_error_total_125_to_149 estimate_total_150_to_184  \
# 1                               41                         0
# 2                               44                        51
# 3                               99                       196
# 4                               75                        20
# 5                                8                        38
#
#   margin_of_error_total_150_to_184 estimate_total_185_to_199  \
# 1                               12                         4
# 2                               46                       118
# 3                              172                         9
# 4                               18                        12
# 5                               32                        49
#
#   margin_of_error_total_185_to_199 estimate_total_200_and_over  \
# 1                                6                         881
# 2                              146                        1089
# 3                               10                         549
# 4                               13                         513
# 5                               42                         749
#
#   margin_of_error_total_200_and_over nan
# 1                                166 NaN
# 2                                239 NaN
# 3                                186 NaN
# 4                                149 NaN
# 5                                234 NaN
#
# [5 rows x 22 columns]

# %%
if 'nan' in data.columns:
    data = data.drop(columns=['nan'])
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total estimate_total_under_50  \
# 1  Missouri           1121                   187                      86
# 2  Missouri           1589                   304                     192
# 3  Missouri            961                   247                      34
# 4  Missouri           1029                   218                      57
# 5  Missouri            998                   247                      28
#
#   margin_of_error_total_under_50 estimate_total_50_to_99  ...  \
# 1                             57                       7  ...
# 2                            250                      65  ...
# 3                             25                      66  ...
# 4                             40                     182  ...
# 5                             26                     125  ...
#
#   estimate_total_100_to_124 margin_of_error_total_100_to_124  \
# 1                        91                              108
# 2                        41                               38
# 3                        10                                8
# 4                       168                              108
# 5                         4                                6
#
#   estimate_total_125_to_149 margin_of_error_total_125_to_149  \
# 1                        52                               41
# 2                        33                               44
# 3                        97                               99
# 4                        77                               75
# 5                         5                                8
#
#   estimate_total_150_to_184 margin_of_error_total_150_to_184  \
# 1                         0                               12
# 2                        51                               46
# 3                       196                              172
# 4                        20                               18
# 5                        38                               32
#
#   estimate_total_185_to_199 margin_of_error_total_185_to_199  \
# 1                         4                                6
# 2                       118                              146
# 3                         9                               10
# 4                        12                               13
# 5                        49                               42
#
#   estimate_total_200_and_over margin_of_error_total_200_and_over
# 1                         881                                166
# 2                        1089                                239
# 3                         549                                186
# 4                         513                                149
# 5                         749                                234
#
# [5 rows x 21 columns]

# %%
data.columns.tolist()
# Out:
# ['geo_id',
#  'block_group',
#  'census_tract',
#  'counties',
#  'state',
#  'estimate_total',
#  'margin_of_error_total',
#  'estimate_total_under_50',
#  'margin_of_error_total_under_50',
#  'estimate_total_50_to_99',
#  'margin_of_error_total_50_to_99',
#  'estimate_total_100_to_124',
#  'margin_of_error_total_100_to_124',
#  'estimate_total_125_to_149',
#  'margin_of_error_total_125_to_149',
#  'estimate_total_150_to_184',
#  'margin_of_error_total_150_to_184',
#  'estimate_total_185_to_199',
#  'margin_of_error_total_185_to_199',
#  'estimate_total_200_and_over',
#  'margin_of_error_total_200_and_over']

# %%
column_mapping = {
    'geo_id': 'geo_id',
    'block_group': 'block_group',
    'census_tract': 'census_tract',
    'counties': 'county',
    'state': 'state',
    'estimate_total': 'est_total',
    'margin_of_error_total': 'moe_total',
    'estimate_total_under_50': 'est_under_50',
    'margin_of_error_total_under_50': 'moe_under_50',
    'estimate_total_50_to_99': 'est_50_to_99',
    'margin_of_error_total_50_to_99': 'moe_50_to_99',
    'estimate_total_100_to_124': 'est_100_to_124',
    'margin_of_error_total_100_to_124': 'moe_100_to_124',
    'estimate_total_125_to_149': 'est_125_to_149',
    'margin_of_error_total_125_to_149': 'moe_125_to_149',
    'estimate_total_150_to_184': 'est_150_to_184',
    'margin_of_error_total_150_to_184': 'moe_150_to_184',
    'estimate_total_185_to_199': 'est_185_to_199',
    'margin_of_error_total_185_to_199': 'moe_185_to_199',
    'estimate_total_200_and_over': 'est_200_plus',
    'margin_of_error_total_200_and_over': 'moe_200_plus'
}

data.rename(columns=column_mapping, inplace=True)
print("Column names after renaming:")
print(data.columns)

numeric_columns = [
    'est_total',
    'moe_total',
    'est_under_50',
    'moe_under_50',
    'est_50_to_99',
    'moe_50_to_99',
    'est_100_to_124',
    'moe_100_to_124',
    'est_125_to_149',
    'moe_125_to_149',
    'est_150_to_184',
    'moe_150_to_184',
    'est_185_to_199',
    'moe_185_to_199',
    'est_200_plus',
    'moe_200_plus']

missing_columns = [col for col in numeric_columns if col not in data.columns]
if missing_columns:
    print(f"These columns are missing after renaming: {missing_columns}")
else:
    data.replace(['**', '***'], np.nan, inplace=True)
    data[numeric_columns] = data[numeric_columns].replace({',': '', '-': np.nan, r'\+': ''}, regex=True)
    data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='raise')

data.fillna('', inplace=True)
if 'nan' in data.columns:
    data.drop(columns=['nan'], inplace=True)
data.head()
# Out:
# Column names after renaming:
# Index(['geo_id', 'block_group', 'census_tract', 'county', 'state', 'est_total',
#        'moe_total', 'est_under_50', 'moe_under_50', 'est_50_to_99',
#        'moe_50_to_99', 'est_100_to_124', 'moe_100_to_124', 'est_125_to_149',
#        'moe_125_to_149', 'est_150_to_184', 'moe_150_to_184', 'est_185_to_199',
#        'moe_185_to_199', 'est_200_plus', 'moe_200_plus'],
#       dtype='object')
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state  est_total  moe_total  est_under_50  moe_under_50  est_50_to_99  \
# 1  Missouri       1121        187            86            57             7
# 2  Missouri       1589        304           192           250            65
# 3  Missouri        961        247            34            25            66
# 4  Missouri       1029        218            57            40           182
# 5  Missouri        998        247            28            26           125
#
#    ...  est_100_to_124  moe_100_to_124  est_125_to_149  moe_125_to_149  \
# 1  ...              91             108              52              41
# 2  ...              41              38              33              44
# 3  ...              10               8              97              99
# 4  ...             168             108              77              75
# 5  ...               4               6               5               8
#
#    est_150_to_184  moe_150_to_184  est_185_to_199  moe_185_to_199  \
# 1               0              12               4               6
# 2              51              46             118             146
# 3             196             172               9              10
# 4              20              18              12              13
# 5              38              32              49              42
#
#    est_200_plus  moe_200_plus
# 1           881           166
# 2          1089           239
# 3           549           186
# 4           513           149
# 5           749           234
#
# [5 rows x 21 columns]

# %%
data['year'] = 2022
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state  est_total  moe_total  est_under_50  moe_under_50  est_50_to_99  \
# 1  Missouri       1121        187            86            57             7
# 2  Missouri       1589        304           192           250            65
# 3  Missouri        961        247            34            25            66
# 4  Missouri       1029        218            57            40           182
# 5  Missouri        998        247            28            26           125
#
#    ...  moe_100_to_124  est_125_to_149  moe_125_to_149  est_150_to_184  \
# 1  ...             108              52              41               0
# 2  ...              38              33              44              51
# 3  ...               8              97              99             196
# 4  ...             108              77              75              20
# 5  ...               6               5               8              38
#
#    moe_150_to_184  est_185_to_199  moe_185_to_199  est_200_plus  moe_200_plus  \
# 1              12               4               6           881           166
# 2              46             118             146          1089           239
# 3             172               9              10           549           186
# 4              18              12              13           513           149
# 5              32              49              42           749           234
#
#    year
# 1  2022
# 2  2022
# 3  2022
# 4  2022
# 5  2022
#
# [5 rows x 22 columns]

# %%
csv_file_path = "2022_Income_to_Poverty_Ratio.csv"
data.to_csv(csv_file_path, index=False)
csv_file_path
# Out:
# '2022_Income_to_Poverty_Ratio.csv'
