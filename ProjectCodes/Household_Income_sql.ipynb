# %%
import psycopg2
from psycopg2 import sql
import numpy as np
import pandas as pd
from psycopg2.extensions import adapt, register_adapter, AsIs
from sqlalchemy import create_engine, text
import getpass

# %%
file_paths = ['2018_Household_Income.csv', 
              '2019_Household_Income.csv',
              '2020_Household_Income.csv', 
              '2021_Household_Income.csv', 
              '2022_Household_Income.csv']

dataframes = [pd.read_csv(file) for file in file_paths]

household_income = pd.concat(dataframes, ignore_index=True)
merged_file_path = 'household_income.csv'
household_income.to_csv(merged_file_path, index=False)
merged_file_path
# Out:
# 'household_income.csv'

# %%
database = "f24t03"
user     = input("Type username (pawprint) and hit enter: ")
password = getpass.getpass("Type password and hit enter: ")

connection = psycopg2.connect(database = database,
                              user     = user,
                              host     = 'pgsql',
                              password = password)
# Out:
# Type username (pawprint) and hit enter: jsmm8
# Type password and hit enter: ········

# %%
with connection, connection.cursor() as cursor:
    cursor.execute("DROP TABLE IF EXISTS household_income;")
    

    cursor.execute(
        '''
        CREATE TABLE household_income (
    geo_id TEXT,
    block_group TEXT,
    census_tract TEXT,
    county TEXT,
    state TEXT,
    est_total INTEGER,
    moe_total INTEGER,
    est_less_than_10k INTEGER,
    moe_less_than_10k INTEGER,
    est_10to15k INTEGER,
    moe_10to15k INTEGER,
    est_15to20k INTEGER,
    moe_15to20k INTEGER,
    est_20to25k INTEGER,
    moe_20to25k INTEGER,
    est_25to30k INTEGER,
    moe_25to30k INTEGER,
    est_30to35k INTEGER,
    moe_30to35k INTEGER,
    est_35to40k INTEGER,
    moe_35to40k INTEGER,
    est_40to45k INTEGER,
    moe_40to45k INTEGER,
    est_45to50k INTEGER,
    moe_45to50k INTEGER,
    est_50to60k INTEGER,
    moe_50to60k INTEGER,
    est_60to75k INTEGER,
    moe_60to75k INTEGER,
    est_75to100k INTEGER,
    moe_75to100k INTEGER,
    est_100to125k INTEGER,
    moe_100to125k INTEGER,
    est_125to150k INTEGER,
    moe_125to150k INTEGER,
    est_150to200k INTEGER,
    moe_150to200k INTEGER,
    est_more_than_200k INTEGER,
    moe_more_than_200k INTEGER,
    year INTEGER,
    PRIMARY KEY (geo_id, year)
    );
    '''
    )

# %%
mypasswd = getpass.getpass("Enter your database password: ")
username = 'jsmm8'
host = 'pgsql'
database = 'f24t03'

conn_string = f"postgresql+psycopg2://{username}:{mypasswd}@{host}/{database}"
engine = create_engine(conn_string)

household_income = 'household_income.csv'

chunk_size = 500

try:
    for chunk in pd.read_csv(household_income, chunksize=chunk_size):
        chunk.to_sql('household_income', engine, if_exists='append', index=False)
        print(f"Uploaded a chunk of {len(chunk)} records to the database.")
    print("CSV data uploaded successfully.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Enter your database password: ········
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# ...

# %%
connection.close()

# %%
grant_privileges_query = "GRANT ALL PRIVILEGES ON TABLE household_income TO ypd5yb, remcmf, sgdky;"

with engine.connect() as connection:
        connection.execute(text(grant_privileges_query))
        print("Privileges granted successfully.")
# Out:
# Privileges granted successfully.
