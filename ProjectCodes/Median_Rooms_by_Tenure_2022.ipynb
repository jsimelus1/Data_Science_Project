# %%
import pandas as pd
import numpy as np

data = pd.read_csv("ACSDT5Y2022.B25021-Data.csv")
data.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US290019501001  Block Group 1; Census Tract 9501; Adair County...
# 2  1500000US290019501002  Block Group 2; Census Tract 9501; Adair County...
# 3  1500000US290019501003  Block Group 3; Census Tract 9501; Adair County...
# 4  1500000US290019502001  Block Group 1; Census Tract 9502; Adair County...
#
#                                    B25021_001E  \
# 0  Estimate!!Median number of rooms --!!Total:
# 1                                          6.4
# 2                                          6.3
# 3                                          5.8
# 4                                          5.6
#
#                                          B25021_001M  \
# 0  Margin of Error!!Median number of rooms --!!To...
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.4
#
#                                          B25021_002E  \
# 0  Estimate!!Median number of rooms --!!Total:!!O...
# 1                                                6.4
# 2                                                6.2
# 3                                                5.9
# 4                                                5.7
#
#                                          B25021_002M  \
# 0  Margin of Error!!Median number of rooms --!!To...
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.3
#
#                                          B25021_003E  \
# 0  Estimate!!Median number of rooms --!!Total:!!R...
# 1                                                5.4
# 2                                                6.5
# 3                                                4.4
# 4                                                4.2
#
#                                          B25021_003M  Unnamed: 8
# 0  Margin of Error!!Median number of rooms --!!To...         NaN
# 1                                                5.9         NaN
# 2                                                0.6         NaN
# 3                                                1.6         NaN
# 4                                                0.5         NaN

# %%
data[['BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE']] = data['NAME'].str.split(';', expand=True)
data.drop(columns=['NAME'], inplace=True)
data['BLOCK_GROUP'] = data['BLOCK_GROUP'].str.strip()
data['CENSUS_TRACT'] = data['CENSUS_TRACT'].str.replace('County', '').str.strip()
data['COUNTIES'] = data['COUNTIES'].str.strip()
data['STATE'] = data['STATE'].str.strip()
data.head()
# Out:
#                   GEO_ID                                  B25021_001E  \
# 0              Geography  Estimate!!Median number of rooms --!!Total:
# 1  1500000US290019501001                                          6.4
# 2  1500000US290019501002                                          6.3
# 3  1500000US290019501003                                          5.8
# 4  1500000US290019502001                                          5.6
#
#                                          B25021_001M  \
# 0  Margin of Error!!Median number of rooms --!!To...
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.4
#
#                                          B25021_002E  \
# 0  Estimate!!Median number of rooms --!!Total:!!O...
# 1                                                6.4
# 2                                                6.2
# 3                                                5.9
# 4                                                5.7
#
#                                          B25021_002M  \
# 0  Margin of Error!!Median number of rooms --!!To...
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.3
#
#                                          B25021_003E  \
# 0  Estimate!!Median number of rooms --!!Total:!!R...
# 1                                                5.4
# 2                                                6.5
# 3                                                4.4
# 4                                                4.2
#
#                                          B25021_003M  Unnamed: 8  \
# 0  Margin of Error!!Median number of rooms --!!To...         NaN
# 1                                                5.9         NaN
# 2                                                0.6         NaN
# 3                                                1.6         NaN
# 4                                                0.5         NaN
#
#             BLOCK_GROUP       CENSUS_TRACT      COUNTIES     STATE
# 0  Geographic Area Name               None          None      None
# 1         Block Group 1  Census Tract 9501  Adair County  Missouri
# 2         Block Group 2  Census Tract 9501  Adair County  Missouri
# 3         Block Group 3  Census Tract 9501  Adair County  Missouri
# 4         Block Group 1  Census Tract 9502  Adair County  Missouri

# %%
data = data[['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + 
            [col for col in data.columns if col not in ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT',
                                                        'COUNTIES', 'STATE']]]
data.head()
# Out:
#                   GEO_ID           BLOCK_GROUP       CENSUS_TRACT  \
# 0              Geography  Geographic Area Name               None
# 1  1500000US290019501001         Block Group 1  Census Tract 9501
# 2  1500000US290019501002         Block Group 2  Census Tract 9501
# 3  1500000US290019501003         Block Group 3  Census Tract 9501
# 4  1500000US290019502001         Block Group 1  Census Tract 9502
#
#        COUNTIES     STATE                                  B25021_001E  \
# 0          None      None  Estimate!!Median number of rooms --!!Total:
# 1  Adair County  Missouri                                          6.4
# 2  Adair County  Missouri                                          6.3
# 3  Adair County  Missouri                                          5.8
# 4  Adair County  Missouri                                          5.6
#
#                                          B25021_001M  \
# 0  Margin of Error!!Median number of rooms --!!To...
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.4
#
#                                          B25021_002E  \
# 0  Estimate!!Median number of rooms --!!Total:!!O...
# 1                                                6.4
# 2                                                6.2
# 3                                                5.9
# 4                                                5.7
#
#                                          B25021_002M  \
# 0  Margin of Error!!Median number of rooms --!!To...
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.3
#
#                                          B25021_003E  \
# 0  Estimate!!Median number of rooms --!!Total:!!R...
# 1                                                5.4
# 2                                                6.5
# 3                                                4.4
# 4                                                4.2
#
#                                          B25021_003M  Unnamed: 8
# 0  Margin of Error!!Median number of rooms --!!To...         NaN
# 1                                                5.9         NaN
# 2                                                0.6         NaN
# 3                                                1.6         NaN
# 4                                                0.5         NaN

# %%
new_headers = data.iloc[0, 5:].tolist()
new_headers = ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + new_headers
data.columns = new_headers
data = data.drop(index=0)
data.head()
# Out:
#                   GEO_ID    BLOCK_GROUP       CENSUS_TRACT      COUNTIES  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       STATE Estimate!!Median number of rooms --!!Total:  \
# 1  Missouri                                         6.4
# 2  Missouri                                         6.3
# 3  Missouri                                         5.8
# 4  Missouri                                         5.6
# 5  Missouri                                         6.4
#
#   Margin of Error!!Median number of rooms --!!Total:  \
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.4
# 5                                                0.6
#
#   Estimate!!Median number of rooms --!!Total:!!Owner occupied  \
# 1                                                6.4
# 2                                                6.2
# 3                                                5.9
# 4                                                5.7
# 5                                                6.5
#
#   Margin of Error!!Median number of rooms --!!Total:!!Owner occupied  \
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.3
# 5                                                0.6
#
#   Estimate!!Median number of rooms --!!Total:!!Renter occupied  \
# 1                                                5.4
# 2                                                6.5
# 3                                                4.4
# 4                                                4.2
# 5                                                5.3
#
#   Margin of Error!!Median number of rooms --!!Total:!!Renter occupied  NaN
# 1                                                5.9                   NaN
# 2                                                0.6                   NaN
# 3                                                1.6                   NaN
# 4                                                0.5                   NaN
# 5                                                2.2                   NaN

# %%
def clean_column_name(column_name):
    column_name = str(column_name)
    column_name = column_name.replace("!!", "_")
    column_name = column_name.replace(" ", "_")
    column_name = column_name.lower()
    column_name = ''.join(char if char.isalnum() or char == '_' else '' for char in column_name)
    return column_name

cleaned_column_names = [clean_column_name(col) for col in data.columns]
data.columns = cleaned_column_names
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_median_number_of_rooms__total  \
# 1  Missouri                                    6.4
# 2  Missouri                                    6.3
# 3  Missouri                                    5.8
# 4  Missouri                                    5.6
# 5  Missouri                                    6.4
#
#   margin_of_error_median_number_of_rooms__total  \
# 1                                           0.7
# 2                                           0.3
# 3                                           0.3
# 4                                           0.4
# 5                                           0.6
#
#   estimate_median_number_of_rooms__total_owner_occupied  \
# 1                                                6.4
# 2                                                6.2
# 3                                                5.9
# 4                                                5.7
# 5                                                6.5
#
#   margin_of_error_median_number_of_rooms__total_owner_occupied  \
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.3
# 5                                                0.6
#
#   estimate_median_number_of_rooms__total_renter_occupied  \
# 1                                                5.4
# 2                                                6.5
# 3                                                4.4
# 4                                                4.2
# 5                                                5.3
#
#   margin_of_error_median_number_of_rooms__total_renter_occupied  nan
# 1                                                5.9             NaN
# 2                                                0.6             NaN
# 3                                                1.6             NaN
# 4                                                0.5             NaN
# 5                                                2.2             NaN

# %%
if 'nan' in data.columns:
    data = data.drop(columns=['nan'])
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_median_number_of_rooms__total  \
# 1  Missouri                                    6.4
# 2  Missouri                                    6.3
# 3  Missouri                                    5.8
# 4  Missouri                                    5.6
# 5  Missouri                                    6.4
#
#   margin_of_error_median_number_of_rooms__total  \
# 1                                           0.7
# 2                                           0.3
# 3                                           0.3
# 4                                           0.4
# 5                                           0.6
#
#   estimate_median_number_of_rooms__total_owner_occupied  \
# 1                                                6.4
# 2                                                6.2
# 3                                                5.9
# 4                                                5.7
# 5                                                6.5
#
#   margin_of_error_median_number_of_rooms__total_owner_occupied  \
# 1                                                0.7
# 2                                                0.3
# 3                                                0.3
# 4                                                0.3
# 5                                                0.6
#
#   estimate_median_number_of_rooms__total_renter_occupied  \
# 1                                                5.4
# 2                                                6.5
# 3                                                4.4
# 4                                                4.2
# 5                                                5.3
#
#   margin_of_error_median_number_of_rooms__total_renter_occupied
# 1                                                5.9
# 2                                                0.6
# 3                                                1.6
# 4                                                0.5
# 5                                                2.2

# %%
data.columns.tolist()
# Out:
# ['geo_id',
#  'block_group',
#  'census_tract',
#  'counties',
#  'state',
#  'estimate_median_number_of_rooms__total',
#  'margin_of_error_median_number_of_rooms__total',
#  'estimate_median_number_of_rooms__total_owner_occupied',
#  'margin_of_error_median_number_of_rooms__total_owner_occupied',
#  'estimate_median_number_of_rooms__total_renter_occupied',
#  'margin_of_error_median_number_of_rooms__total_renter_occupied']

# %%
column_mapping = {
    'geo_id': 'geo_id',
    'block_group': 'block_group',
    'census_tract': 'census_tract',
    'counties': 'county',
    'state': 'state',
    'estimate_median_number_of_rooms__total': 'est_median_rooms_total',
    'margin_of_error_median_number_of_rooms__total': 'moe_median_rooms_total',
    'estimate_median_number_of_rooms__total_owner_occupied': 'est_median_rooms_owner',
    'margin_of_error_median_number_of_rooms__total_owner_occupied': 'moe_median_rooms_owner',
    'estimate_median_number_of_rooms__total_renter_occupied': 'est_median_rooms_renter',
    'margin_of_error_median_number_of_rooms__total_renter_occupied': 'moe_median_rooms_renter'
}

data.rename(columns=column_mapping, inplace=True)
print("Column names after renaming:")
print(data.columns)

numeric_columns = [
    'est_median_rooms_total',
    'moe_median_rooms_total',
    'est_median_rooms_owner',
    'moe_median_rooms_owner',
    'est_median_rooms_renter',
    'moe_median_rooms_renter'
]

missing_columns = [col for col in numeric_columns if col not in data.columns]
if missing_columns:
    print(f"These columns are missing after renaming: {missing_columns}")
else:
    data.replace(['**', '***'], np.nan, inplace=True)
    data[numeric_columns] = data[numeric_columns].replace({',': '', '-': np.nan, r'\+': ''}, regex=True)
    data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='raise')

data.fillna('', inplace=True)
if 'nan' in data.columns:
    data.drop(columns=['nan'], inplace=True)
data.head()
# Out:
# Column names after renaming:
# Index(['geo_id', 'block_group', 'census_tract', 'county', 'state',
#        'est_median_rooms_total', 'moe_median_rooms_total',
#        'est_median_rooms_owner', 'moe_median_rooms_owner',
#        'est_median_rooms_renter', 'moe_median_rooms_renter'],
#       dtype='object')
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state est_median_rooms_total moe_median_rooms_total  \
# 1  Missouri                    6.4                    0.7
# 2  Missouri                    6.3                    0.3
# 3  Missouri                    5.8                    0.3
# 4  Missouri                    5.6                    0.4
# 5  Missouri                    6.4                    0.6
#
#   est_median_rooms_owner moe_median_rooms_owner est_median_rooms_renter  \
# 1                    6.4                    0.7                     5.4
# 2                    6.2                    0.3                     6.5
# 3                    5.9                    0.3                     4.4
# 4                    5.7                    0.3                     4.2
# 5                    6.5                    0.6                     5.3
#
#   moe_median_rooms_renter
# 1                     5.9
# 2                     0.6
# 3                     1.6
# 4                     0.5
# 5                     2.2

# %%
data['year'] = 2022
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state est_median_rooms_total moe_median_rooms_total  \
# 1  Missouri                    6.4                    0.7
# 2  Missouri                    6.3                    0.3
# 3  Missouri                    5.8                    0.3
# 4  Missouri                    5.6                    0.4
# 5  Missouri                    6.4                    0.6
#
#   est_median_rooms_owner moe_median_rooms_owner est_median_rooms_renter  \
# 1                    6.4                    0.7                     5.4
# 2                    6.2                    0.3                     6.5
# 3                    5.9                    0.3                     4.4
# 4                    5.7                    0.3                     4.2
# 5                    6.5                    0.6                     5.3
#
#   moe_median_rooms_renter  year
# 1                     5.9  2022
# 2                     0.6  2022
# 3                     1.6  2022
# 4                     0.5  2022
# 5                     2.2  2022

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5031 entries, 1 to 5031
# Data columns (total 12 columns):
# geo_id                     5031 non-null object
# block_group                5031 non-null object
# census_tract               5031 non-null object
# county                     5031 non-null object
# state                      5031 non-null object
# est_median_rooms_total     5031 non-null object
# moe_median_rooms_total     5031 non-null object
# est_median_rooms_owner     5031 non-null object
# moe_median_rooms_owner     5031 non-null object
# est_median_rooms_renter    5031 non-null object
# moe_median_rooms_renter    5031 non-null object
# year                       5031 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 511.0+ KB

# %%
csv_file_path = "2022_Median_Rooms_by_Tenure.csv"
data.to_csv(csv_file_path, index=False)
csv_file_path
# Out:
# '2022_Median_Rooms_by_Tenure.csv'
