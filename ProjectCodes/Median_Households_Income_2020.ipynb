# %%
import pandas as pd
import numpy as np

data = pd.read_csv("ACSDT5Y2020.B19013-Data.csv")
data.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US290019501001  Block Group 1, Census Tract 9501, Adair County...
# 2  1500000US290019501002  Block Group 2, Census Tract 9501, Adair County...
# 3  1500000US290019501003  Block Group 3, Census Tract 9501, Adair County...
# 4  1500000US290019502001  Block Group 1, Census Tract 9502, Adair County...
#
#                                          B19013_001E  \
# 0  Estimate!!Median household income in the past ...
# 1                                              56313
# 2                                              57167
# 3                                              48409
# 4                                              34911
#
#                                          B19013_001M
# 0  Margin of Error!!Median household income in th...
# 1                                               2840
# 2                                              16907
# 3                                               5803
# 4                                               7714

# %%
data[['BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE']] = data['NAME'].str.split(',', expand=True)
data.drop(columns=['NAME'], inplace=True)
data['BLOCK_GROUP'] = data['BLOCK_GROUP'].str.strip()
data['CENSUS_TRACT'] = data['CENSUS_TRACT'].str.replace('County', '').str.strip()
data['COUNTIES'] = data['COUNTIES'].str.strip()
data['STATE'] = data['STATE'].str.strip()
data.head()
# Out:
#                   GEO_ID                                        B19013_001E  \
# 0              Geography  Estimate!!Median household income in the past ...
# 1  1500000US290019501001                                              56313
# 2  1500000US290019501002                                              57167
# 3  1500000US290019501003                                              48409
# 4  1500000US290019502001                                              34911
#
#                                          B19013_001M           BLOCK_GROUP  \
# 0  Margin of Error!!Median household income in th...  Geographic Area Name
# 1                                               2840         Block Group 1
# 2                                              16907         Block Group 2
# 3                                               5803         Block Group 3
# 4                                               7714         Block Group 1
#
#         CENSUS_TRACT      COUNTIES     STATE
# 0               None          None      None
# 1  Census Tract 9501  Adair County  Missouri
# 2  Census Tract 9501  Adair County  Missouri
# 3  Census Tract 9501  Adair County  Missouri
# 4  Census Tract 9502  Adair County  Missouri

# %%
data = data[['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + 
            [col for col in data.columns if col not in ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT',
                                                        'COUNTIES', 'STATE']]]
data.head()
# Out:
#                   GEO_ID           BLOCK_GROUP       CENSUS_TRACT  \
# 0              Geography  Geographic Area Name               None
# 1  1500000US290019501001         Block Group 1  Census Tract 9501
# 2  1500000US290019501002         Block Group 2  Census Tract 9501
# 3  1500000US290019501003         Block Group 3  Census Tract 9501
# 4  1500000US290019502001         Block Group 1  Census Tract 9502
#
#        COUNTIES     STATE                                        B19013_001E  \
# 0          None      None  Estimate!!Median household income in the past ...
# 1  Adair County  Missouri                                              56313
# 2  Adair County  Missouri                                              57167
# 3  Adair County  Missouri                                              48409
# 4  Adair County  Missouri                                              34911
#
#                                          B19013_001M
# 0  Margin of Error!!Median household income in th...
# 1                                               2840
# 2                                              16907
# 3                                               5803
# 4                                               7714

# %%
new_headers = data.iloc[0, 5:].tolist()
new_headers = ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + new_headers 
data.columns = new_headers
data = data.drop(index=0)
data.head()
# Out:
#                   GEO_ID    BLOCK_GROUP       CENSUS_TRACT      COUNTIES  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       STATE  \
# 1  Missouri
# 2  Missouri
# 3  Missouri
# 4  Missouri
# 5  Missouri
#
#   Estimate!!Median household income in the past 12 months (in 2020 inflation-adjusted dollars)  \
# 1                                              56313
# 2                                              57167
# 3                                              48409
# 4                                              34911
# 5                                              54141
#
#   Margin of Error!!Median household income in the past 12 months (in 2020 inflation-adjusted dollars)
# 1                                               2840
# 2                                              16907
# 3                                               5803
# 4                                               7714
# 5                                              10685

# %%
data.columns = data.columns.astype(str)
def clean_column_name(column_name):
    column_name = column_name.replace("!!", "_")
    column_name = column_name.replace(" ", "_")
    column_name = column_name.lower()
    column_name = ''.join(char if char.isalnum() or char == '_' else '' for char in column_name)
    return column_name

cleaned_column_names = [clean_column_name(col) for col in data.columns]
data.columns = cleaned_column_names
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state  \
# 1  Missouri
# 2  Missouri
# 3  Missouri
# 4  Missouri
# 5  Missouri
#
#   estimate_median_household_income_in_the_past_12_months_in_2020_inflationadjusted_dollars  \
# 1                                              56313
# 2                                              57167
# 3                                              48409
# 4                                              34911
# 5                                              54141
#
#   margin_of_error_median_household_income_in_the_past_12_months_in_2020_inflationadjusted_dollars
# 1                                               2840
# 2                                              16907
# 3                                               5803
# 4                                               7714
# 5                                              10685

# %%
data.columns.tolist()
# Out:
# ['geo_id',
#  'block_group',
#  'census_tract',
#  'counties',
#  'state',
#  'estimate_median_household_income_in_the_past_12_months_in_2020_inflationadjusted_dollars',
#  'margin_of_error_median_household_income_in_the_past_12_months_in_2020_inflationadjusted_dollars']

# %%
column_mapping = {
    'geo_id': 'geo_id',
    'block_group': 'block_group',
    'census_tract': 'census_tract',
    'counties': 'county',
    'state': 'state',
    'estimate_median_household_income_in_the_past_12_months_in_2020_inflationadjusted_dollars': 'est_inflated_past_12_months_median_income',
    'margin_of_error_median_household_income_in_the_past_12_months_in_2020_inflationadjusted_dollars': 'moe_inflated_past_12_months_median_income',
}

data.rename(columns=column_mapping, inplace=True)
print("Column names after renaming:")
print(data.columns)

numeric_columns = ['est_inflated_past_12_months_median_income', 'moe_inflated_past_12_months_median_income']
missing_columns = [col for col in numeric_columns if col not in data.columns]
if missing_columns:
    print(f"These columns are missing after renaming: {missing_columns}")
else:
    data.replace(['-', '**', '***'], '', inplace=True)
    data = data.replace(to_replace=r'(\d+)[-+]', value=r'\1', regex=True)
    data[numeric_columns] = data[numeric_columns].replace({',': ''}, regex=True)
    data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='raise')

data.fillna('', inplace=True)
if 'nan' in data.columns:
    data.drop(columns=['nan'], inplace=True)
data.head()
# Out:
# Column names after renaming:
# Index(['geo_id', 'block_group', 'census_tract', 'county', 'state',
#        'est_inflated_past_12_months_median_income',
#        'moe_inflated_past_12_months_median_income'],
#       dtype='object')
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state est_inflated_past_12_months_median_income  \
# 1  Missouri                                   56313.0
# 2  Missouri                                   57167.0
# 3  Missouri                                   48409.0
# 4  Missouri                                   34911.0
# 5  Missouri                                   54141.0
#
#   moe_inflated_past_12_months_median_income
# 1                                    2840.0
# 2                                   16907.0
# 3                                    5803.0
# 4                                    7714.0
# 5                                   10685.0

# %%
data['year'] = 2020
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state est_inflated_past_12_months_median_income  \
# 1  Missouri                                   56313.0
# 2  Missouri                                   57167.0
# 3  Missouri                                   48409.0
# 4  Missouri                                   34911.0
# 5  Missouri                                   54141.0
#
#   moe_inflated_past_12_months_median_income  year
# 1                                    2840.0  2020
# 2                                   16907.0  2020
# 3                                    5803.0  2020
# 4                                    7714.0  2020
# 5                                   10685.0  2020

# %%
csv_file_path = "2020_Median_Households_Income.csv"
data.to_csv(csv_file_path, index=False)
csv_file_path
# Out:
# '2020_Median_Households_Income.csv'

# %%
rows_with_2500 = data[(data == 2500).any(axis=1)]
print(rows_with_2500)
# Out:
#                      geo_id    block_group         census_tract  \
# 2101  1500000US290950154012  Block Group 2  Census Tract 154.01
#
#               county     state est_inflated_past_12_months_median_income  \
# 2101  Jackson County  Missouri                                    2500.0
#
#      moe_inflated_past_12_months_median_income  year
# 2101                                            2020
