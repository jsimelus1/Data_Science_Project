# %%
import pandas as pd

data = pd.read_csv("ACSDT5Y2020.B15002-Data.csv")
data.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US290019501001  Block Group 1, Census Tract 9501, Adair County...
# 2  1500000US290019501002  Block Group 2, Census Tract 9501, Adair County...
# 3  1500000US290019501003  Block Group 3, Census Tract 9501, Adair County...
# 4  1500000US290019502001  Block Group 1, Census Tract 9502, Adair County...
#
#         B15002_001E              B15002_001M              B15002_002E  \
# 0  Estimate!!Total:  Margin of Error!!Total:  Estimate!!Total:!!Male:
# 1               846                      146                      440
# 2               931                      163                      470
# 3               616                      107                      307
# 4               638                      117                      352
#
#                       B15002_002M  \
# 0  Margin of Error!!Total:!!Male:
# ...

# %%
data[['BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE']] = data['NAME'].str.split(',', expand=True)
data.drop(columns=['NAME'], inplace=True)
data['BLOCK_GROUP'] = data['BLOCK_GROUP'].str.strip()
data['CENSUS_TRACT'] = data['CENSUS_TRACT'].str.replace('County', '').str.strip()
data['COUNTIES'] = data['COUNTIES'].str.strip()
data['STATE'] = data['STATE'].str.strip()
data.head()
# Out:
#                   GEO_ID       B15002_001E              B15002_001M  \
# 0              Geography  Estimate!!Total:  Margin of Error!!Total:
# 1  1500000US290019501001               846                      146
# 2  1500000US290019501002               931                      163
# 3  1500000US290019501003               616                      107
# 4  1500000US290019502001               638                      117
#
#                B15002_002E                     B15002_002M  \
# 0  Estimate!!Total:!!Male:  Margin of Error!!Total:!!Male:
# 1                      440                              96
# 2                      470                              94
# 3                      307                              66
# 4                      352                              81
#
#                                        B15002_003E  \
# 0  Estimate!!Total:!!Male:!!No schooling completed
# 1                                                0
# ...

# %%
data = data[['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + 
            [col for col in data.columns if col not in ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT',
                                                        'COUNTIES', 'STATE']]]
data.head()
# Out:
#                   GEO_ID           BLOCK_GROUP       CENSUS_TRACT  \
# 0              Geography  Geographic Area Name               None
# 1  1500000US290019501001         Block Group 1  Census Tract 9501
# 2  1500000US290019501002         Block Group 2  Census Tract 9501
# 3  1500000US290019501003         Block Group 3  Census Tract 9501
# 4  1500000US290019502001         Block Group 1  Census Tract 9502
#
#        COUNTIES     STATE       B15002_001E              B15002_001M  \
# 0          None      None  Estimate!!Total:  Margin of Error!!Total:
# 1  Adair County  Missouri               846                      146
# 2  Adair County  Missouri               931                      163
# 3  Adair County  Missouri               616                      107
# 4  Adair County  Missouri               638                      117
#
#                B15002_002E                     B15002_002M  \
# 0  Estimate!!Total:!!Male:  Margin of Error!!Total:!!Male:
# ...

# %%
new_headers = data.iloc[0, 5:].tolist()
new_headers = ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + new_headers
data.columns = new_headers
data = data.drop(index=0)
data.head()
# Out:
#                   GEO_ID    BLOCK_GROUP       CENSUS_TRACT      COUNTIES  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       STATE Estimate!!Total: Margin of Error!!Total: Estimate!!Total:!!Male:  \
# 1  Missouri              846                     146                     440
# 2  Missouri              931                     163                     470
# 3  Missouri              616                     107                     307
# 4  Missouri              638                     117                     352
# 5  Missouri              651                     129                     350
#
#   Margin of Error!!Total:!!Male:  \
# ...

# %%
def clean_column_name(column_name):
    column_name = column_name.replace("!!", "_")
    column_name = column_name.replace(" ", "_")
    column_name = column_name.lower()
    column_name = ''.join(char if char.isalnum() or char == '_' else '' for char in column_name)
    return column_name

cleaned_column_names = [clean_column_name(col) for col in data.columns]
data.columns = cleaned_column_names
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total estimate_total_male  \
# 1  Missouri            846                   146                 440
# 2  Missouri            931                   163                 470
# 3  Missouri            616                   107                 307
# 4  Missouri            638                   117                 352
# 5  Missouri            651                   129                 350
#
#   margin_of_error_total_male estimate_total_male_no_schooling_completed  ...  \
# ...

# %%
data.columns.tolist()
# Out:
# ['geo_id',
#  'block_group',
#  'census_tract',
#  'counties',
#  'state',
#  'estimate_total',
#  'margin_of_error_total',
#  'estimate_total_male',
#  'margin_of_error_total_male',
#  'estimate_total_male_no_schooling_completed',
#  'margin_of_error_total_male_no_schooling_completed',
#  'estimate_total_male_nursery_to_4th_grade',
#  'margin_of_error_total_male_nursery_to_4th_grade',
#  'estimate_total_male_5th_and_6th_grade',
#  'margin_of_error_total_male_5th_and_6th_grade',
#  'estimate_total_male_7th_and_8th_grade',
#  'margin_of_error_total_male_7th_and_8th_grade',
#  'estimate_total_male_9th_grade',
#  'margin_of_error_total_male_9th_grade',
#  'estimate_total_male_10th_grade',
#  'margin_of_error_total_male_10th_grade',
#  'estimate_total_male_11th_grade',
#  'margin_of_error_total_male_11th_grade',
#  'estimate_total_male_12th_grade_no_diploma',
#  'margin_of_error_total_male_12th_grade_no_diploma',
#  'estimate_total_male_high_school_graduate_includes_equivalency',
# ...

# %%
column_mapping = {
    'geo_id': 'geo_id',
    'block_group': 'block_group',
    'census_tract': 'census_tract',
    'counties': 'county',
    'state': 'state',
    'estimate_total': 'estimate_total',
    'margin_of_error_total': 'margin_of_error_total',
    'estimate_total_male': 'estimate_total_male',
    'margin_of_error_total_male': 'margin_of_error_total_male',
    'estimate_total_male_no_schooling_completed': 'male_no_schooling_completed',
    'margin_of_error_total_male_no_schooling_completed': 'moe_male_no_schooling_comp',
    'estimate_total_male_nursery_to_4th_grade': 'est_male_pre_k_to_4th_grade',
    'margin_of_error_total_male_nursery_to_4th_grade': 'moe_male_pre_k_to_4th_grade',
    'estimate_total_male_5th_and_6th_grade': 'est_male_5th_6th_grade',
    'margin_of_error_total_male_5th_and_6th_grade': 'moe_male_5th_6th_grade',
    'estimate_total_male_7th_and_8th_grade': 'est_male_7th_8th_grade',
    'margin_of_error_total_male_7th_and_8th_grade': 'moe_male_7th_8th_grade',
    'estimate_total_male_9th_grade': 'est_male_9th_grade',
    'margin_of_error_total_male_9th_grade': 'moe_male_9th_grade',
    'estimate_total_male_10th_grade': 'est_male_10th_grade',
    'margin_of_error_total_male_10th_grade': 'moe_male_10th_grade',
    'estimate_total_male_11th_grade': 'est_male_11th_grade',
    'margin_of_error_total_male_11th_grade': 'moe_male_11th_grade',
    'estimate_total_male_12th_grade_no_diploma': 'est_male_12th_grade_no_diploma',
    'margin_of_error_total_male_12th_grade_no_diploma': 'moe_male_12th_grade_no_diploma',
    'estimate_total_male_high_school_graduate_includes_equivalency': 'est_male_hs_graduate_includes_equivalency',
    'margin_of_error_total_male_high_school_graduate_includes_equivalency': 'moe_male_hs_graduate_includes_equivalency',
    'estimate_total_male_some_college_less_than_1_year': 'est_male_some_college_less_than_1_year',
    'margin_of_error_total_male_some_college_less_than_1_year': 'moe_male_some_college_less_than_1_year',
    'estimate_total_male_some_college_1_or_more_years_no_degree': 'est_male_some_college_over_1_years_no_degree',
    'margin_of_error_total_male_some_college_1_or_more_years_no_degree': 'moe_male_some_college_over_1_years_no_degree',
    'estimate_total_male_associates_degree': 'est_male_as_degree',
    'margin_of_error_total_male_associates_degree': 'moe_male_as_degree',
    'estimate_total_male_bachelors_degree': 'est_male_bs_degree',
    'margin_of_error_total_male_bachelors_degree': 'moe_male_bs_degree',
    'estimate_total_male_masters_degree': 'est_male_ms_degree',
    'margin_of_error_total_male_masters_degree': 'moe_male_ms_degree',
    'estimate_total_male_professional_school_degree': 'est_male_pro_school_degree',
    'margin_of_error_total_male_professional_school_degree': 'moe_male_pro_school_degree',
    'estimate_total_male_doctorate_degree': 'est_male_phd_degree',
    'margin_of_error_total_male_doctorate_degree': 'moe_male_phd_degree',
    'estimate_total_female': 'estimate_total_female',
    'margin_of_error_total_female': 'margin_of_error_total_female',
    'estimate_total_female_no_schooling_completed': 'female_no_schooling_completed',
    'margin_of_error_total_female_no_schooling_completed': 'moe_female_no_schooling_completed',
    'estimate_total_female_nursery_to_4th_grade': 'est_female_pre_k_to_4th_grade',
    'margin_of_error_total_female_nursery_to_4th_grade': 'moe_female_pre_k_to_4th_grade',
    'estimate_total_female_5th_and_6th_grade': 'est_female_5th_6th_grade',
    'margin_of_error_total_female_5th_and_6th_grade': 'moe_est_female_5th_6th_grade',
    'estimate_total_female_7th_and_8th_grade': 'est_female_7th_8th_grade',
    'margin_of_error_total_female_7th_and_8th_grade': 'moe_female_7th_8th_grade',
    'estimate_total_female_9th_grade': 'est_female_9th_grade',
    'margin_of_error_total_female_9th_grade': 'moe_female_9th_grade',
    'estimate_total_female_10th_grade': 'est_female_10th_grade',
    'margin_of_error_total_female_10th_grade': 'moe_female_10th_grade',
    'estimate_total_female_11th_grade': 'est_female_11th_grade',
    'margin_of_error_total_female_11th_grade': 'moe_female_11th_grade',
    'estimate_total_female_12th_grade_no_diploma': 'est_female_12th_grade_no_diploma',
    'margin_of_error_total_female_12th_grade_no_diploma': 'moe_female_12th_grade_no_diploma',
    'estimate_total_female_high_school_graduate_includes_equivalency': 'est_female_hs_graduate_includes_equivalency',
    'margin_of_error_total_female_high_school_graduate_includes_equivalency': 'moe_female_hs_graduate_includes_equivalency',
    'estimate_total_female_some_college_less_than_1_year': 'est_female_some_college_less_than_1_year',
    'margin_of_error_total_female_some_college_less_than_1_year': 'moe_female_some_college_less_than_1_year',
    'estimate_total_female_some_college_1_or_more_years_no_degree': 'est_female_some_college_over_1_years_no_degree',
    'margin_of_error_total_female_some_college_1_or_more_years_no_degree': 'moe_female_some_college_over_1_years_no_degree',
    'estimate_total_female_associates_degree': 'estimate_female_as_degree',
    'margin_of_error_total_female_associates_degree': 'moe_female_as_degree',
    'estimate_total_female_bachelors_degree': 'est_female_bs_degree',
    'margin_of_error_total_female_bachelors_degree': 'moe_female_bs_degree',
    'estimate_total_female_masters_degree': 'est_female_ms_degree',
    'margin_of_error_total_female_masters_degree': 'moe_female_ms_degree',
    'estimate_total_female_professional_school_degree': 'est_female_pro_school_degree',
    'margin_of_error_total_female_professional_school_degree': 'moe_female_pro_school_degree',
    'estimate_total_female_doctorate_degree': 'est_female_phd_degree',
    'margin_of_error_total_female_doctorate_degree': 'moe_female_phd_degree'
}

data.rename(columns=column_mapping, inplace=True)
data.replace(['-', '**'], 'N/A', inplace=True)
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total estimate_total_male  \
# 1  Missouri            846                   146                 440
# 2  Missouri            931                   163                 470
# 3  Missouri            616                   107                 307
# 4  Missouri            638                   117                 352
# 5  Missouri            651                   129                 350
#
#   margin_of_error_total_male male_no_schooling_completed  ...  \
# ...

# %%
data['year'] = 2020
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total estimate_total_male  \
# 1  Missouri            846                   146                 440
# 2  Missouri            931                   163                 470
# 3  Missouri            616                   107                 307
# 4  Missouri            638                   117                 352
# 5  Missouri            651                   129                 350
#
#   margin_of_error_total_male male_no_schooling_completed  ...  \
# ...

# %%
csv_file_path = "2020_Educational_Attainment.csv"
data.to_csv(csv_file_path, index=False)
csv_file_path
# Out:
# '2020_Educational_Attainment.csv'
