# %%
import pandas as pd
import numpy as np

data = pd.read_csv("ACSDT5Y2021.B25049-Data.csv")
data.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US290019501001  Block Group 1, Census Tract 9501, Adair County...
# 2  1500000US290019501002  Block Group 2, Census Tract 9501, Adair County...
# 3  1500000US290019501003  Block Group 3, Census Tract 9501, Adair County...
# 4  1500000US290019502001  Block Group 1, Census Tract 9502, Adair County...
#
#         B25049_001E              B25049_001M  \
# 0  Estimate!!Total:  Margin of Error!!Total:
# 1               427                       70
# 2               546                       87
# 3               339                       59
# 4               326                       65
#
#                          B25049_002E  \
# 0  Estimate!!Total:!!Owner occupied:
# 1                                411
# 2                                482
# 3                                298
# 4                                265
#
#                                 B25049_002M  \
# 0  Margin of Error!!Total:!!Owner occupied:
# 1                                        70
# 2                                        86
# 3                                        57
# 4                                        58
#
#                                          B25049_003E  \
# 0  Estimate!!Total:!!Owner occupied:!!Complete pl...
# 1                                                398
# 2                                                482
# 3                                                288
# 4                                                265
#
#                                          B25049_003M  \
# 0  Margin of Error!!Total:!!Owner occupied:!!Comp...
# 1                                                 69
# 2                                                 86
# 3                                                 58
# 4                                                 58
#
#                                          B25049_004E  \
# 0  Estimate!!Total:!!Owner occupied:!!Lacking plu...
# 1                                                 13
# 2                                                  0
# 3                                                 10
# 4                                                  0
#
#                                          B25049_004M  \
# 0  Margin of Error!!Total:!!Owner occupied:!!Lack...
# 1                                                 19
# 2                                                 12
# 3                                                 11
# 4                                                 12
#
#                           B25049_005E  \
# 0  Estimate!!Total:!!Renter occupied:
# 1                                  16
# 2                                  64
# 3                                  41
# 4                                  61
#
#                                  B25049_005M  \
# 0  Margin of Error!!Total:!!Renter occupied:
# 1                                         16
# 2                                         41
# 3                                         23
# 4                                         25
#
#                                          B25049_006E  \
# 0  Estimate!!Total:!!Renter occupied:!!Complete p...
# 1                                                 16
# 2                                                 64
# 3                                                 24
# 4                                                 61
#
#                                          B25049_006M  \
# 0  Margin of Error!!Total:!!Renter occupied:!!Com...
# 1                                                 16
# 2                                                 41
# 3                                                 12
# 4                                                 25
#
#                                          B25049_007E  \
# 0  Estimate!!Total:!!Renter occupied:!!Lacking pl...
# 1                                                  0
# 2                                                  0
# 3                                                 17
# 4                                                  0
#
#                                          B25049_007M  Unnamed: 16
# 0  Margin of Error!!Total:!!Renter occupied:!!Lac...          NaN
# 1                                                 12          NaN
# 2                                                 12          NaN
# 3                                                 19          NaN
# 4                                                 12          NaN

# %%
# Splitting the 'NAME' column by commas
data[['BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE']] = data['NAME'].str.split(',', expand=True)

# Dropping the 'NAME' column
data.drop(columns=['NAME'], inplace=True)

# Cleaning up the GEOGRAPHIC_AREA_NAME, COUNTIES, and STATE columns
data['BLOCK_GROUP'] = data['BLOCK_GROUP'].str.strip()
data['CENSUS_TRACT'] = data['CENSUS_TRACT'].str.replace('County', '').str.strip()
data['COUNTIES'] = data['COUNTIES'].str.strip()
data['STATE'] = data['STATE'].str.strip()

data.head()
# Out:
#                   GEO_ID       B25049_001E              B25049_001M  \
# 0              Geography  Estimate!!Total:  Margin of Error!!Total:
# 1  1500000US290019501001               427                       70
# 2  1500000US290019501002               546                       87
# 3  1500000US290019501003               339                       59
# 4  1500000US290019502001               326                       65
#
#                          B25049_002E  \
# 0  Estimate!!Total:!!Owner occupied:
# 1                                411
# 2                                482
# 3                                298
# 4                                265
#
#                                 B25049_002M  \
# 0  Margin of Error!!Total:!!Owner occupied:
# 1                                        70
# 2                                        86
# 3                                        57
# 4                                        58
#
#                                          B25049_003E  \
# 0  Estimate!!Total:!!Owner occupied:!!Complete pl...
# 1                                                398
# 2                                                482
# 3                                                288
# 4                                                265
#
#                                          B25049_003M  \
# 0  Margin of Error!!Total:!!Owner occupied:!!Comp...
# 1                                                 69
# 2                                                 86
# 3                                                 58
# 4                                                 58
#
#                                          B25049_004E  \
# 0  Estimate!!Total:!!Owner occupied:!!Lacking plu...
# 1                                                 13
# 2                                                  0
# 3                                                 10
# 4                                                  0
#
#                                          B25049_004M  \
# 0  Margin of Error!!Total:!!Owner occupied:!!Lack...
# 1                                                 19
# 2                                                 12
# 3                                                 11
# 4                                                 12
#
#                           B25049_005E  \
# 0  Estimate!!Total:!!Renter occupied:
# 1                                  16
# 2                                  64
# 3                                  41
# 4                                  61
#
#                                  B25049_005M  \
# 0  Margin of Error!!Total:!!Renter occupied:
# 1                                         16
# 2                                         41
# 3                                         23
# 4                                         25
#
#                                          B25049_006E  \
# 0  Estimate!!Total:!!Renter occupied:!!Complete p...
# 1                                                 16
# 2                                                 64
# 3                                                 24
# 4                                                 61
#
#                                          B25049_006M  \
# 0  Margin of Error!!Total:!!Renter occupied:!!Com...
# 1                                                 16
# 2                                                 41
# 3                                                 12
# 4                                                 25
#
#                                          B25049_007E  \
# 0  Estimate!!Total:!!Renter occupied:!!Lacking pl...
# 1                                                  0
# 2                                                  0
# 3                                                 17
# 4                                                  0
#
#                                          B25049_007M  Unnamed: 16  \
# 0  Margin of Error!!Total:!!Renter occupied:!!Lac...          NaN
# 1                                                 12          NaN
# 2                                                 12          NaN
# 3                                                 19          NaN
# 4                                                 12          NaN
#
#             BLOCK_GROUP       CENSUS_TRACT      COUNTIES     STATE
# 0  Geographic Area Name               None          None      None
# 1         Block Group 1  Census Tract 9501  Adair County  Missouri
# 2         Block Group 2  Census Tract 9501  Adair County  Missouri
# 3         Block Group 3  Census Tract 9501  Adair County  Missouri
# 4         Block Group 1  Census Tract 9502  Adair County  Missouri

# %%
# Reorder the new columns 'TRACT', 'COUNTY', 'STATE' to be the second, third, and fourth columns
data = data[['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + 
            [col for col in data.columns if col not in ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT',
                                                        'COUNTIES', 'STATE']]]

data.head()
# Out:
#                   GEO_ID           BLOCK_GROUP       CENSUS_TRACT  \
# 0              Geography  Geographic Area Name               None
# 1  1500000US290019501001         Block Group 1  Census Tract 9501
# 2  1500000US290019501002         Block Group 2  Census Tract 9501
# 3  1500000US290019501003         Block Group 3  Census Tract 9501
# 4  1500000US290019502001         Block Group 1  Census Tract 9502
#
#        COUNTIES     STATE       B25049_001E              B25049_001M  \
# 0          None      None  Estimate!!Total:  Margin of Error!!Total:
# 1  Adair County  Missouri               427                       70
# 2  Adair County  Missouri               546                       87
# 3  Adair County  Missouri               339                       59
# 4  Adair County  Missouri               326                       65
#
#                          B25049_002E  \
# 0  Estimate!!Total:!!Owner occupied:
# 1                                411
# 2                                482
# 3                                298
# 4                                265
#
#                                 B25049_002M  \
# 0  Margin of Error!!Total:!!Owner occupied:
# 1                                        70
# 2                                        86
# 3                                        57
# 4                                        58
#
#                                          B25049_003E  \
# 0  Estimate!!Total:!!Owner occupied:!!Complete pl...
# 1                                                398
# 2                                                482
# 3                                                288
# 4                                                265
#
#                                          B25049_003M  \
# 0  Margin of Error!!Total:!!Owner occupied:!!Comp...
# 1                                                 69
# 2                                                 86
# 3                                                 58
# 4                                                 58
#
#                                          B25049_004E  \
# 0  Estimate!!Total:!!Owner occupied:!!Lacking plu...
# 1                                                 13
# 2                                                  0
# 3                                                 10
# 4                                                  0
#
#                                          B25049_004M  \
# 0  Margin of Error!!Total:!!Owner occupied:!!Lack...
# 1                                                 19
# 2                                                 12
# 3                                                 11
# 4                                                 12
#
#                           B25049_005E  \
# 0  Estimate!!Total:!!Renter occupied:
# 1                                  16
# 2                                  64
# 3                                  41
# 4                                  61
#
#                                  B25049_005M  \
# 0  Margin of Error!!Total:!!Renter occupied:
# 1                                         16
# 2                                         41
# 3                                         23
# 4                                         25
#
#                                          B25049_006E  \
# 0  Estimate!!Total:!!Renter occupied:!!Complete p...
# 1                                                 16
# 2                                                 64
# 3                                                 24
# 4                                                 61
#
#                                          B25049_006M  \
# 0  Margin of Error!!Total:!!Renter occupied:!!Com...
# 1                                                 16
# 2                                                 41
# 3                                                 12
# 4                                                 25
#
#                                          B25049_007E  \
# 0  Estimate!!Total:!!Renter occupied:!!Lacking pl...
# 1                                                  0
# 2                                                  0
# 3                                                 17
# 4                                                  0
#
#                                          B25049_007M  Unnamed: 16
# 0  Margin of Error!!Total:!!Renter occupied:!!Lac...          NaN
# 1                                                 12          NaN
# 2                                                 12          NaN
# 3                                                 19          NaN
# 4                                                 12          NaN

# %%
# Save the original headers
new_headers = data.iloc[0, 5:].tolist()
new_headers = ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + new_headers

# Replace the headers of the dataframe
data.columns = new_headers

# Drop the first row, as it's now part of the headers
data = data.drop(index=0)

# Display the first few rows of the updated dataset
data.head()
# Out:
#                   GEO_ID    BLOCK_GROUP       CENSUS_TRACT      COUNTIES  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       STATE Estimate!!Total: Margin of Error!!Total:  \
# 1  Missouri              427                      70
# 2  Missouri              546                      87
# 3  Missouri              339                      59
# 4  Missouri              326                      65
# 5  Missouri              345                      79
#
#   Estimate!!Total:!!Owner occupied: Margin of Error!!Total:!!Owner occupied:  \
# 1                               411                                       70
# 2                               482                                       86
# 3                               298                                       57
# 4                               265                                       58
# 5                               304                                       70
#
#   Estimate!!Total:!!Owner occupied:!!Complete plumbing facilities  \
# 1                                                398
# 2                                                482
# 3                                                288
# 4                                                265
# 5                                                304
#
#   Margin of Error!!Total:!!Owner occupied:!!Complete plumbing facilities  \
# 1                                                 69
# 2                                                 86
# 3                                                 58
# 4                                                 58
# 5                                                 70
#
#   Estimate!!Total:!!Owner occupied:!!Lacking plumbing facilities  \
# 1                                                 13
# 2                                                  0
# 3                                                 10
# 4                                                  0
# 5                                                  0
#
#   Margin of Error!!Total:!!Owner occupied:!!Lacking plumbing facilities  \
# 1                                                 19
# 2                                                 12
# 3                                                 11
# 4                                                 12
# 5                                                 12
#
#   Estimate!!Total:!!Renter occupied:  \
# 1                                 16
# 2                                 64
# 3                                 41
# 4                                 61
# 5                                 41
#
#   Margin of Error!!Total:!!Renter occupied:  \
# 1                                        16
# 2                                        41
# 3                                        23
# 4                                        25
# 5                                        28
#
#   Estimate!!Total:!!Renter occupied:!!Complete plumbing facilities  \
# 1                                                 16
# 2                                                 64
# 3                                                 24
# 4                                                 61
# 5                                                 41
#
#   Margin of Error!!Total:!!Renter occupied:!!Complete plumbing facilities  \
# 1                                                 16
# 2                                                 41
# 3                                                 12
# 4                                                 25
# 5                                                 28
#
#   Estimate!!Total:!!Renter occupied:!!Lacking plumbing facilities  \
# 1                                                  0
# 2                                                  0
# 3                                                 17
# 4                                                  0
# 5                                                  0
#
#   Margin of Error!!Total:!!Renter occupied:!!Lacking plumbing facilities  NaN
# 1                                                 12                      NaN
# 2                                                 12                      NaN
# 3                                                 19                      NaN
# 4                                                 12                      NaN
# 5                                                 12                      NaN

# %%
# Let's clean and standardize the column names
def clean_column_name(column_name):
    # Convert the column name to a string first
    column_name = str(column_name)
    # Replace "!!" with "_"
    column_name = column_name.replace("!!", "_")
    # Replace spaces with underscores
    column_name = column_name.replace(" ", "_")
    # Convert to lowercase
    column_name = column_name.lower()
    # Remove any characters that are not alphanumeric or underscores
    column_name = ''.join(char if char.isalnum() or char == '_' else '' for char in column_name)
    return column_name

# Apply this function to all column names
cleaned_column_names = [clean_column_name(col) for col in data.columns]

# Rename the dataset columns
data.columns = cleaned_column_names

# Display the first few rows of the dataset with the new column names
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total  \
# 1  Missouri            427                    70
# 2  Missouri            546                    87
# 3  Missouri            339                    59
# 4  Missouri            326                    65
# 5  Missouri            345                    79
#
#   estimate_total_owner_occupied margin_of_error_total_owner_occupied  \
# 1                           411                                   70
# 2                           482                                   86
# 3                           298                                   57
# 4                           265                                   58
# 5                           304                                   70
#
#   estimate_total_owner_occupied_complete_plumbing_facilities  \
# 1                                                398
# 2                                                482
# 3                                                288
# 4                                                265
# 5                                                304
#
#   margin_of_error_total_owner_occupied_complete_plumbing_facilities  \
# 1                                                 69
# 2                                                 86
# 3                                                 58
# 4                                                 58
# 5                                                 70
#
#   estimate_total_owner_occupied_lacking_plumbing_facilities  \
# 1                                                 13
# 2                                                  0
# 3                                                 10
# 4                                                  0
# 5                                                  0
#
#   margin_of_error_total_owner_occupied_lacking_plumbing_facilities  \
# 1                                                 19
# 2                                                 12
# 3                                                 11
# 4                                                 12
# 5                                                 12
#
#   estimate_total_renter_occupied margin_of_error_total_renter_occupied  \
# 1                             16                                    16
# 2                             64                                    41
# 3                             41                                    23
# 4                             61                                    25
# 5                             41                                    28
#
#   estimate_total_renter_occupied_complete_plumbing_facilities  \
# 1                                                 16
# 2                                                 64
# 3                                                 24
# 4                                                 61
# 5                                                 41
#
#   margin_of_error_total_renter_occupied_complete_plumbing_facilities  \
# 1                                                 16
# 2                                                 41
# 3                                                 12
# 4                                                 25
# 5                                                 28
#
#   estimate_total_renter_occupied_lacking_plumbing_facilities  \
# 1                                                  0
# 2                                                  0
# 3                                                 17
# 4                                                  0
# 5                                                  0
#
#   margin_of_error_total_renter_occupied_lacking_plumbing_facilities  nan
# 1                                                 12                 NaN
# 2                                                 12                 NaN
# 3                                                 19                 NaN
# 4                                                 12                 NaN
# 5                                                 12                 NaN

# %%
if 'nan' in data.columns:
    data = data.drop(columns=['nan'])
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total  \
# 1  Missouri            427                    70
# 2  Missouri            546                    87
# 3  Missouri            339                    59
# 4  Missouri            326                    65
# 5  Missouri            345                    79
#
#   estimate_total_owner_occupied margin_of_error_total_owner_occupied  \
# 1                           411                                   70
# 2                           482                                   86
# 3                           298                                   57
# 4                           265                                   58
# 5                           304                                   70
#
#   estimate_total_owner_occupied_complete_plumbing_facilities  \
# 1                                                398
# 2                                                482
# 3                                                288
# 4                                                265
# 5                                                304
#
#   margin_of_error_total_owner_occupied_complete_plumbing_facilities  \
# 1                                                 69
# 2                                                 86
# 3                                                 58
# 4                                                 58
# 5                                                 70
#
#   estimate_total_owner_occupied_lacking_plumbing_facilities  \
# 1                                                 13
# 2                                                  0
# 3                                                 10
# 4                                                  0
# 5                                                  0
#
#   margin_of_error_total_owner_occupied_lacking_plumbing_facilities  \
# 1                                                 19
# 2                                                 12
# 3                                                 11
# 4                                                 12
# 5                                                 12
#
#   estimate_total_renter_occupied margin_of_error_total_renter_occupied  \
# 1                             16                                    16
# 2                             64                                    41
# 3                             41                                    23
# 4                             61                                    25
# 5                             41                                    28
#
#   estimate_total_renter_occupied_complete_plumbing_facilities  \
# 1                                                 16
# 2                                                 64
# 3                                                 24
# 4                                                 61
# 5                                                 41
#
#   margin_of_error_total_renter_occupied_complete_plumbing_facilities  \
# 1                                                 16
# 2                                                 41
# 3                                                 12
# 4                                                 25
# 5                                                 28
#
#   estimate_total_renter_occupied_lacking_plumbing_facilities  \
# 1                                                  0
# 2                                                  0
# 3                                                 17
# 4                                                  0
# 5                                                  0
#
#   margin_of_error_total_renter_occupied_lacking_plumbing_facilities
# 1                                                 12
# 2                                                 12
# 3                                                 19
# 4                                                 12
# 5                                                 12

# %%
data.columns.tolist()
# Out:
# ['geo_id',
#  'block_group',
#  'census_tract',
#  'counties',
#  'state',
#  'estimate_total',
#  'margin_of_error_total',
#  'estimate_total_owner_occupied',
#  'margin_of_error_total_owner_occupied',
#  'estimate_total_owner_occupied_complete_plumbing_facilities',
#  'margin_of_error_total_owner_occupied_complete_plumbing_facilities',
#  'estimate_total_owner_occupied_lacking_plumbing_facilities',
#  'margin_of_error_total_owner_occupied_lacking_plumbing_facilities',
#  'estimate_total_renter_occupied',
#  'margin_of_error_total_renter_occupied',
#  'estimate_total_renter_occupied_complete_plumbing_facilities',
#  'margin_of_error_total_renter_occupied_complete_plumbing_facilities',
#  'estimate_total_renter_occupied_lacking_plumbing_facilities',
#  'margin_of_error_total_renter_occupied_lacking_plumbing_facilities']

# %%
# Creating a mapping from long column names to shorter names
column_mapping = {
    'geo_id': 'geo_id',
    'block_group': 'block_group',
    'census_tract': 'census_tract',
    'counties': 'county',
    'state': 'state',
    'estimate_total': 'est_total',
    'margin_of_error_total': 'moe_total',
    'estimate_total_owner_occupied': 'est_own_occ',
    'margin_of_error_total_owner_occupied': 'moe_own_occ',
    'estimate_total_owner_occupied_complete_plumbing_facilities': 'est_own_occ_plumb_complete',
    'margin_of_error_total_owner_occupied_complete_plumbing_facilities': 'moe_own_occ_plumb_complete',
    'estimate_total_owner_occupied_lacking_plumbing_facilities': 'est_own_occ_plumb_lack',
    'margin_of_error_total_owner_occupied_lacking_plumbing_facilities': 'moe_own_occ_plumb_lack',
    'estimate_total_renter_occupied': 'est_rent_occ',
    'margin_of_error_total_renter_occupied': 'moe_rent_occ',
    'estimate_total_renter_occupied_complete_plumbing_facilities': 'est_rent_occ_plumb_complete',
    'margin_of_error_total_renter_occupied_complete_plumbing_facilities': 'moe_rent_occ_plumb_complete',
    'estimate_total_renter_occupied_lacking_plumbing_facilities': 'est_rent_occ_plumb_lack',
    'margin_of_error_total_renter_occupied_lacking_plumbing_facilities': 'moe_rent_occ_plumb_lack'
}

# Renaming the columns in the dataset
data.rename(columns=column_mapping, inplace=True)

# Print column names to check if renaming worked
print("Column names after renaming:")
print(data.columns)

# Ensure the columns exist before applying further operations
numeric_columns = [
    'est_total',
    'moe_total',
    'est_own_occ',
    'moe_own_occ',
    'est_own_occ_plumb_complete',
    'moe_own_occ_plumb_complete',
    'est_own_occ_plumb_lack',
    'moe_own_occ_plumb_lack',
    'est_rent_occ',
    'moe_rent_occ',
    'est_rent_occ_plumb_complete',
    'moe_rent_occ_plumb_complete',
    'est_rent_occ_plumb_lack',
    'moe_rent_occ_plumb_lack'
]

# Check if the columns exist in the DataFrame
missing_columns = [col for col in numeric_columns if col not in data.columns]
if missing_columns:
    print(f"These columns are missing after renaming: {missing_columns}")
else:
    # Replace '**' and '***' with NaN to clean the data
    data.replace(['**', '***'], np.nan, inplace=True)

    # Remove any other non-numeric characters, including commas, hyphens, and plus signs
    data[numeric_columns] = data[numeric_columns].replace({',': '', '-': np.nan, r'\+': ''}, regex=True)

    # Convert the numeric columns to numeric type after cleaning
    data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='raise')

# Replace all NaN values with blank (empty string) to prepare for database ingestion
data.fillna('', inplace=True)

# Dropping any columns named 'nan' (if they exist)
if 'nan' in data.columns:
    data.drop(columns=['nan'], inplace=True)

# Displaying the first few rows of the cleaned data
data.head()
# Out:
# Column names after renaming:
# Index(['geo_id', 'block_group', 'census_tract', 'county', 'state', 'est_total',
#        'moe_total', 'est_own_occ', 'moe_own_occ', 'est_own_occ_plumb_complete',
#        'moe_own_occ_plumb_complete', 'est_own_occ_plumb_lack',
#        'moe_own_occ_plumb_lack', 'est_rent_occ', 'moe_rent_occ',
#        'est_rent_occ_plumb_complete', 'moe_rent_occ_plumb_complete',
#        'est_rent_occ_plumb_lack', 'moe_rent_occ_plumb_lack'],
#       dtype='object')
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state  est_total  moe_total  est_own_occ  moe_own_occ  \
# 1  Missouri        427         70          411           70
# 2  Missouri        546         87          482           86
# 3  Missouri        339         59          298           57
# 4  Missouri        326         65          265           58
# 5  Missouri        345         79          304           70
#
#    est_own_occ_plumb_complete  moe_own_occ_plumb_complete  \
# 1                         398                          69
# 2                         482                          86
# 3                         288                          58
# 4                         265                          58
# 5                         304                          70
#
#    est_own_occ_plumb_lack  moe_own_occ_plumb_lack  est_rent_occ  moe_rent_occ  \
# 1                      13                      19            16            16
# 2                       0                      12            64            41
# 3                      10                      11            41            23
# 4                       0                      12            61            25
# 5                       0                      12            41            28
#
#    est_rent_occ_plumb_complete  moe_rent_occ_plumb_complete  \
# 1                           16                           16
# 2                           64                           41
# 3                           24                           12
# 4                           61                           25
# 5                           41                           28
#
#    est_rent_occ_plumb_lack  moe_rent_occ_plumb_lack
# 1                        0                       12
# 2                        0                       12
# 3                       17                       19
# 4                        0                       12
# 5                        0                       12

# %%
data['year'] = 2021
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state  est_total  moe_total  est_own_occ  moe_own_occ  \
# 1  Missouri        427         70          411           70
# 2  Missouri        546         87          482           86
# 3  Missouri        339         59          298           57
# 4  Missouri        326         65          265           58
# 5  Missouri        345         79          304           70
#
#    est_own_occ_plumb_complete  moe_own_occ_plumb_complete  \
# 1                         398                          69
# 2                         482                          86
# 3                         288                          58
# 4                         265                          58
# 5                         304                          70
#
#    est_own_occ_plumb_lack  moe_own_occ_plumb_lack  est_rent_occ  moe_rent_occ  \
# 1                      13                      19            16            16
# 2                       0                      12            64            41
# 3                      10                      11            41            23
# 4                       0                      12            61            25
# 5                       0                      12            41            28
#
#    est_rent_occ_plumb_complete  moe_rent_occ_plumb_complete  \
# 1                           16                           16
# 2                           64                           41
# 3                           24                           12
# 4                           61                           25
# 5                           41                           28
#
#    est_rent_occ_plumb_lack  moe_rent_occ_plumb_lack  year
# 1                        0                       12  2021
# 2                        0                       12  2021
# 3                       17                       19  2021
# 4                        0                       12  2021
# 5                        0                       12  2021

# %%
csv_file_path = "2021_Tenure_by_Plumbing.csv"
data.to_csv(csv_file_path, index=False)

# Provide the file link for download
csv_file_path
# Out:
# '2021_Tenure_by_Plumbing.csv'
