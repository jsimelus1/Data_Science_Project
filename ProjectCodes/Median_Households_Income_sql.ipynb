# %%
import psycopg2
from psycopg2 import sql
import numpy as np
import pandas as pd
from psycopg2.extensions import adapt, register_adapter, AsIs
from sqlalchemy import create_engine, text
import getpass

# %%
file_paths = ['2018_Median_Households_Income.csv', 
              '2019_Median_Households_Income.csv',
              '2020_Median_Households_Income.csv', 
              '2021_Median_Households_Income.csv', 
              '2022_Median_Households_Income.csv']

dataframes = [pd.read_csv(file) for file in file_paths]
Median_Households_Income = pd.concat(dataframes, ignore_index=True)
merged_file_path = 'median_household_income.csv'
Median_Households_Income.to_csv(merged_file_path, index=False)
merged_file_path
# Out:
# 'median_household_income.csv'

# %%
database = "f24t03"
user     = input("Type username (pawprint) and hit enter: ")
password = getpass.getpass("Type password and hit enter: ")

connection = psycopg2.connect(database = database,
                              user     = user,
                              host     = 'pgsql',
                              password = password)
# Out:
# Type username (pawprint) and hit enter: jsmm8
# Type password and hit enter: ········

# %%
with connection, connection.cursor() as cursor:
    cursor.execute("DROP TABLE IF EXISTS median_household_income;")
    

    cursor.execute(
        '''
        CREATE TABLE median_household_income (
    geo_id TEXT,
    block_group TEXT,
    census_tract TEXT,
    county TEXT,
    state TEXT,
    est_inflated_past_12_months_median_income TEXT,
    moe_inflated_past_12_months_median_income INTEGER,
    year INTEGER,
    PRIMARY KEY (geo_id, year)
    );
        '''
    )

# %%
mypasswd = getpass.getpass("Enter your database password: ")
username = 'jsmm8'
host = 'pgsql'
database = 'f24t03'

conn_string = f"postgresql+psycopg2://{username}:{mypasswd}@{host}/{database}"
engine = create_engine(conn_string)

median_household_income = 'median_household_income.csv'

chunk_size = 500

try:
    for chunk in pd.read_csv(median_household_income, chunksize=chunk_size):
        chunk.to_sql('median_household_income', engine, if_exists='append', index=False)
        print(f"Uploaded a chunk of {len(chunk)} records to the database.")
    print("CSV data uploaded successfully.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Enter your database password: ········
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# Uploaded a chunk of 500 records to the database.
# ...

# %%
grant_privileges_query = "GRANT ALL PRIVILEGES ON TABLE median_household_income TO ypd5yb, remcmf, sgdky;"

with engine.connect() as connection:
        connection.execute(text(grant_privileges_query))
        print("Privileges granted successfully.")
# Out:
# Privileges granted successfully.

# %%
connection.close()

# %%
select_query = "SELECT * FROM median_household_income LIMIT 10;" 

with engine.connect() as connection:
    result = connection.execute(text(select_query))
    df = pd.DataFrame(result.fetchall(), columns=result.keys())
print("Query executed successfully.")
df
# Out:
# Query executed successfully.
#                   geo_id    block_group       census_tract        county  \
# 0  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 1  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 2  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 3  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 4  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
# 5  1500000US290019502003  Block Group 3  Census Tract 9502  Adair County
# 6  1500000US290019503001  Block Group 1  Census Tract 9503  Adair County
# 7  1500000US290019503002  Block Group 2  Census Tract 9503  Adair County
# 8  1500000US290019503003  Block Group 3  Census Tract 9503  Adair County
# 9  1500000US290019503004  Block Group 4  Census Tract 9503  Adair County
#
#       state est_inflated_past_12_months_median_income  \
# 0  Missouri                                   54821.0
# ...
