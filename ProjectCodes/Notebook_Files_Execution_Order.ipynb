# %% [markdown]
# # Notebook Files Execution Order

# %% [raw]
# ethnicity
# educational_attainment
# household_income
# median_household_income
# employment_status
# occupancy_status
# tenure_by_rooms
# median_rooms_by_tenure
# year_structure_built
# tenure_by_bedrooms
# tenure_by_plumbing
# tenure_by_kitchen
# home_value
# median_home_value
# mortgage_status
# income_to_poverty_ratio
# Education_EDA
# Median_Home_Value_Imputation_1
# Housing_data_merge_and_pct_stats_2
# Housing_pct_change_stats_data_3
# new_datasets_merge_4
# 01_Race
# 02_01_Imputation_with_confidence_measure - random synthetic approach
# 02_02_Income
# 03_Education and Final Demographics
# 04_EDA
# 05_Feature_Selection_and_Model
# 06_Neural_Network Regression (Hellbender Run)
# Moran’s I
# GWR
# Final_Testing
#
# #############CAPSTONE NOTEBOOK EXECUTION SEQUENCE#############
#
# gdb_upload.ipynb
# distance_calc.ipynb
# flood_join.ipynb
# 01_Capstone_Preprocessing_Code.ipynb
# 02_Geo_Layers_Risk_Measures.ipynb
# Springfield_EDA-Updated__1_.ipynb
# GoogleValidation.ipynb
# scoring_models.ipynb
# model_validation.ipynb
# Interface.ipynb

# %% [markdown]
# **Note :** Shapefiles are not available in team03 folder as we are unable to push any shapefiles into the git repository. We tried to add the shapefiles into database, but we don’t have privilege to create a geoDB table in postgres.
