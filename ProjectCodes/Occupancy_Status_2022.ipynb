# %%
import pandas as pd

data = pd.read_csv("ACSDT5Y2022.B25002-Data.csv")
data.head()
# Out:
#                   GEO_ID                                               NAME  \
# 0              Geography                               Geographic Area Name
# 1  1500000US290019501001  Block Group 1; Census Tract 9501; Adair County...
# 2  1500000US290019501002  Block Group 2; Census Tract 9501; Adair County...
# 3  1500000US290019501003  Block Group 3; Census Tract 9501; Adair County...
# 4  1500000US290019502001  Block Group 1; Census Tract 9502; Adair County...
#
#         B25002_001E              B25002_001M                 B25002_002E  \
# 0  Estimate!!Total:  Margin of Error!!Total:  Estimate!!Total:!!Occupied
# 1               577                       86                         427
# 2               692                      103                         612
# 3               449                       71                         317
# 4               481                       86                         322
#
#                          B25002_002M               B25002_003E  \
# 0  Margin of Error!!Total:!!Occupied  Estimate!!Total:!!Vacant
# 1                                 74                       150
# 2                                100                        80
# 3                                 64                       132
# 4                                 70                       159
#
#                        B25002_003M  Unnamed: 8
# 0  Margin of Error!!Total:!!Vacant         NaN
# 1                               61         NaN
# 2                               45         NaN
# 3                               43         NaN
# 4                               59         NaN

# %%
data[['BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE']] = data['NAME'].str.split(';', expand=True)
data.drop(columns=['NAME'], inplace=True)
data['BLOCK_GROUP'] = data['BLOCK_GROUP'].str.strip()
data['CENSUS_TRACT'] = data['CENSUS_TRACT'].str.replace('County', '').str.strip()
data['COUNTIES'] = data['COUNTIES'].str.strip()
data['STATE'] = data['STATE'].str.strip()
data.drop(columns=['Unnamed: 8'], inplace=True)
data.head()
# Out:
#                   GEO_ID       B25002_001E              B25002_001M  \
# 0              Geography  Estimate!!Total:  Margin of Error!!Total:
# 1  1500000US290019501001               577                       86
# 2  1500000US290019501002               692                      103
# 3  1500000US290019501003               449                       71
# 4  1500000US290019502001               481                       86
#
#                   B25002_002E                        B25002_002M  \
# 0  Estimate!!Total:!!Occupied  Margin of Error!!Total:!!Occupied
# 1                         427                                 74
# 2                         612                                100
# 3                         317                                 64
# 4                         322                                 70
#
#                 B25002_003E                      B25002_003M  \
# 0  Estimate!!Total:!!Vacant  Margin of Error!!Total:!!Vacant
# 1                       150                               61
# 2                        80                               45
# 3                       132                               43
# 4                       159                               59
#
#             BLOCK_GROUP       CENSUS_TRACT      COUNTIES     STATE
# 0  Geographic Area Name               None          None      None
# 1         Block Group 1  Census Tract 9501  Adair County  Missouri
# 2         Block Group 2  Census Tract 9501  Adair County  Missouri
# 3         Block Group 3  Census Tract 9501  Adair County  Missouri
# 4         Block Group 1  Census Tract 9502  Adair County  Missouri

# %%
data = data[['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + 
            [col for col in data.columns if col not in ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT',
                                                        'COUNTIES', 'STATE']]]
data.head()
# Out:
#                   GEO_ID           BLOCK_GROUP       CENSUS_TRACT  \
# 0              Geography  Geographic Area Name               None
# 1  1500000US290019501001         Block Group 1  Census Tract 9501
# 2  1500000US290019501002         Block Group 2  Census Tract 9501
# 3  1500000US290019501003         Block Group 3  Census Tract 9501
# 4  1500000US290019502001         Block Group 1  Census Tract 9502
#
#        COUNTIES     STATE       B25002_001E              B25002_001M  \
# 0          None      None  Estimate!!Total:  Margin of Error!!Total:
# 1  Adair County  Missouri               577                       86
# 2  Adair County  Missouri               692                      103
# 3  Adair County  Missouri               449                       71
# 4  Adair County  Missouri               481                       86
#
#                   B25002_002E                        B25002_002M  \
# 0  Estimate!!Total:!!Occupied  Margin of Error!!Total:!!Occupied
# 1                         427                                 74
# 2                         612                                100
# 3                         317                                 64
# 4                         322                                 70
#
#                 B25002_003E                      B25002_003M
# 0  Estimate!!Total:!!Vacant  Margin of Error!!Total:!!Vacant
# 1                       150                               61
# 2                        80                               45
# 3                       132                               43
# 4                       159                               59

# %%
new_headers = data.iloc[0, 5:].tolist() 
new_headers = ['GEO_ID', 'BLOCK_GROUP', 'CENSUS_TRACT', 'COUNTIES', 'STATE'] + new_headers
data.columns = new_headers
data = data.drop(index=0)
data.head()
# Out:
#                   GEO_ID    BLOCK_GROUP       CENSUS_TRACT      COUNTIES  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       STATE Estimate!!Total: Margin of Error!!Total:  \
# 1  Missouri              577                      86
# 2  Missouri              692                     103
# 3  Missouri              449                      71
# 4  Missouri              481                      86
# 5  Missouri              508                      95
#
#   Estimate!!Total:!!Occupied Margin of Error!!Total:!!Occupied  \
# 1                        427                                74
# 2                        612                               100
# 3                        317                                64
# 4                        322                                70
# 5                        378                                88
#
#   Estimate!!Total:!!Vacant Margin of Error!!Total:!!Vacant
# 1                      150                              61
# 2                       80                              45
# 3                      132                              43
# 4                      159                              59
# 5                      130                              50

# %%
data.columns = data.columns.astype(str)
def clean_column_name(column_name):
    column_name = column_name.replace("!!", "_")
    column_name = column_name.replace(" ", "_")
    column_name = column_name.lower()
    column_name = ''.join(char if char.isalnum() or char == '_' else '' for char in column_name)
    return column_name

cleaned_column_names = [clean_column_name(col) for col in data.columns]
data.columns = cleaned_column_names
data.head()
# Out:
#                   geo_id    block_group       census_tract      counties  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state estimate_total margin_of_error_total estimate_total_occupied  \
# 1  Missouri            577                    86                     427
# 2  Missouri            692                   103                     612
# 3  Missouri            449                    71                     317
# 4  Missouri            481                    86                     322
# 5  Missouri            508                    95                     378
#
#   margin_of_error_total_occupied estimate_total_vacant  \
# 1                             74                   150
# 2                            100                    80
# 3                             64                   132
# 4                             70                   159
# 5                             88                   130
#
#   margin_of_error_total_vacant
# 1                           61
# 2                           45
# 3                           43
# 4                           59
# 5                           50

# %%
column_mapping = {
    'geo_id': 'geo_id',
    'block_group': 'block_group',
    'census_tract': 'census_tract',
    'counties': 'county',
    'state': 'state',
    'estimate_total': 'total_estimate',
    'margin_of_error_total': 'total_margin_of_error',
    'estimate_total_occupied': 'est_total_occupied',
    'margin_of_error_total_occupied': 'moe_total_occupied',
    'estimate_total_vacant': 'est_total_vacant',
    'margin_of_error_total_vacant': 'margin_of_error_total_vacant'
}

data.rename(columns=column_mapping, inplace=True)
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state total_estimate total_margin_of_error est_total_occupied  \
# 1  Missouri            577                    86                427
# 2  Missouri            692                   103                612
# 3  Missouri            449                    71                317
# 4  Missouri            481                    86                322
# 5  Missouri            508                    95                378
#
#   moe_total_occupied est_total_vacant margin_of_error_total_vacant
# 1                 74              150                           61
# 2                100               80                           45
# 3                 64              132                           43
# 4                 70              159                           59
# 5                 88              130                           50

# %%
data['year'] = 2022
data.head()
# Out:
#                   geo_id    block_group       census_tract        county  \
# 1  1500000US290019501001  Block Group 1  Census Tract 9501  Adair County
# 2  1500000US290019501002  Block Group 2  Census Tract 9501  Adair County
# 3  1500000US290019501003  Block Group 3  Census Tract 9501  Adair County
# 4  1500000US290019502001  Block Group 1  Census Tract 9502  Adair County
# 5  1500000US290019502002  Block Group 2  Census Tract 9502  Adair County
#
#       state total_estimate total_margin_of_error est_total_occupied  \
# 1  Missouri            577                    86                427
# 2  Missouri            692                   103                612
# 3  Missouri            449                    71                317
# 4  Missouri            481                    86                322
# 5  Missouri            508                    95                378
#
#   moe_total_occupied est_total_vacant margin_of_error_total_vacant  year
# 1                 74              150                           61  2022
# 2                100               80                           45  2022
# 3                 64              132                           43  2022
# 4                 70              159                           59  2022
# 5                 88              130                           50  2022

# %%
csv_file_path = "2022_Occupancy_Status.csv"
data.to_csv(csv_file_path, index=False)
csv_file_path
# Out:
# '2022_Occupancy_Status.csv'
